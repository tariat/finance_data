# %% [markdown]
# ### 삼성전자 볼린저밴드 포트폴리오 평가

# %%
import pyfolio as pf
import pandas as pd

ss_bb = pd.read_pickle("samsung_bollingerbands.pkl")

# %%
pf.create_full_tear_sheet(ss_bb.returns)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-02-07</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-04-23</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>14</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>11.8%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>14.2%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>18.2%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.70</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.60</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.07</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-19.7%</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### 삼성전자 매일 매수 방법과 비교

# %%
ss_buy=pd.read_pickle("samsung_daily_buy.pkl")

# %%
ss_bb_per=pf.timeseries.perf_stats(ss_bb.returns)[["Annual volatility","Annual return","Cumulative returns", "Max drawdown", "Sharpe ratio", "Sortino ratio"]]
ss_buy_per=pf.timeseries.perf_stats(ss_buy.returns)[["Annual volatility","Annual return","Cumulative returns", "Max drawdown", "Sharpe ratio", "Sortino ratio"]]
# Out:
# /Users/open/anaconda3/envs/env_zipline/lib/python3.5/site-packages/empyrical/stats.py:1477: RuntimeWarning: invalid value encountered in log1p
#   cum_log_returns = np.log1p(returns).cumsum()

# %%
per_tot=pd.DataFrame({"BollingerBands":ss_bb_per,"Daily Buy":ss_buy_per})

# %%
per_tot.T
# Out:
#                 Annual volatility  Annual return  Cumulative returns  \
# BollingerBands           0.181608       0.117561            0.141976
# Daily Buy               53.401262       0.207508            0.252602
#
#                 Max drawdown  Sharpe ratio  Sortino ratio
# BollingerBands     -0.196846      0.702013       1.127534
# Daily Buy          -1.183963      0.590710       1.780836
