# %%
# %load_ext zipline

# %%
# %%zipline --start 2019-1-2 --end 2020-4-21 --bundle kor_stocks --trading-calendar XKRX
# from zipline.api import order, record, symbol
#
# def initialize(context):
#     pass
#
# def handle_data(context,data):
#     order(symbol('005930'),10)
#     record(samsung=data.current(symbol('005930'), 'price'))
# Out:
#                            algo_volatility  algorithm_period_return alpha  \
# 2019-01-02 06:30:00+00:00              NaN                 0.000000  None
# 2019-01-03 06:30:00+00:00         0.000211                -0.000019  None
# 2019-01-04 06:30:00+00:00         0.001468                -0.000188  None
# 2019-01-07 06:30:00+00:00         0.021017                 0.002393  None
# 2019-01-08 06:30:00+00:00         0.025735                 0.000424  None
# 2019-01-09 06:30:00+00:00         0.044585                 0.006404  None
# 2019-01-10 06:30:00+00:00         0.040704                 0.007384  None
# 2019-01-11 06:30:00+00:00         0.041495                 0.011564  None
# 2019-01-14 06:30:00+00:00         0.045746                 0.008394  None
# 2019-01-15 06:30:00+00:00         0.056846                 0.016774  None
# 2019-01-16 06:30:00+00:00         0.054348                 0.019903  None
# 2019-01-17 06:30:00+00:00         0.053710                 0.024882  None
# ...

# %%
perf=_

# %%
import pandas as pd

# 소수점 출력형식 조정
pd.set_option('display.float_format', '{:.2f}'.format)
perf["portfolio_value"]=perf["portfolio_value"].astype(int)
print(perf.head().T)
# Out:
#                                                  2019-01-02 06:30:00+00:00  \
# algo_volatility                                                        NaN
# algorithm_period_return                                               0.00
# alpha                                                                 None
# benchmark_period_return                                               0.00
# benchmark_volatility                                                   NaN
# beta                                                                  None
# capital_used                                                          0.00
# ending_cash                                                    10000000.00
# ending_exposure                                                       0.00
# ending_value                                                          0.00
# excess_return                                                         0.00
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

plt.rcParams["figure.figsize"] = (14,8)
ax1 = plt.subplot(211)

fmt = '{x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax1.yaxis.set_major_formatter(tick)

g=sns.lineplot(x=perf.index,y=perf["portfolio_value"], ax=ax1)

ax2 = plt.subplot(212)
sns.lineplot(x=perf.index,y=perf["samsung"], ax=ax2)
